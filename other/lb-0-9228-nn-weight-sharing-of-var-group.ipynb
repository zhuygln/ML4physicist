# %% [markdown]
# ** Somehow it is very slow running on kernel please change the values when running offline.**

# %%
RUN_FOLDS = 1
EPOCHS = 1
BATCHSIZE = 128
# please change to the following values offline
# RUN_FOLDS = 5
# EPOCHS = 50

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm, tqdm_notebook
import time
import glob
import os
print(os.listdir("../input"))
import gc


# Any results you write to the current directory are saved as output.
import tensorflow as tf
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from keras import layers
from keras import backend as K
from keras import regularizers
from keras.constraints import max_norm
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.models import Model
from keras.initializers import glorot_uniform
from keras.layers import Input,Dense,Activation,ZeroPadding2D,BatchNormalization,Flatten,Conv2D,AveragePooling2D,MaxPooling2D,Dropout,concatenate
from sklearn import preprocessing

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
#from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from keras.utils import Sequence,to_categorical

GPU = 4
os.environ['CUDA_VISIBLE_DEVICES'] = str(GPU)

import datetime
import os
import sys
import time

import random
import multiprocessing

import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ae3474d76f36> in <module>
#       5 import glob
#       6 import os
# ----> 7 print(os.listdir("../input"))
#       8 import gc
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input'

# %%
def reverse(tr,cols=None):
    reverse_list = [0,1,2,3,4,5,6,7,8,11,15,16,18,19,
                22,24,25,26,27,41,29,
                32,35,37,40,48,49,47,
                55,51,52,53,60,61,62,103,65,66,67,69,
                70,71,74,78,79,
                82,84,89,90,91,94,95,96,97,99,
                105,106,110,111,112,118,119,125,128,
                130,133,134,135,137,138,
                140,144,145,147,151,155,157,159,
                161,162,163,164,167,168,
                170,171,173,175,176,179,
                180,181,184,185,187,189,
                190,191,195,196,199]
    reverse_list = ['var_%d'%i for i in reverse_list]
    if cols is not None:
        for col in cols:
            colx = col.split('_')
            colx = '_'.join(colx[:2])
            if colx in reverse_list:
                print('reverse',col)
                tr[col] = tr[col]*(-1)
        return tr
    
    for col in reverse_list:
        tr[col] = tr[col]*(-1)
    return tr

def scale(tr,te=None):
    for col in tr.columns:
        if col.startswith('var_'):
            mean,std = tr[col].mean(),tr[col].std()
            tr[col] = (tr[col]-mean)/std
            if te is not None:
                te[col] = (te[col]-mean)/std
    if te is None:
        return tr
    return tr,te

def getp_vec_sum(x,x_sort,y,std,c=0.5):
    # x is sorted
    left = x - std/c
    right = x + std/c
    p_left = np.searchsorted(x_sort,left)
    p_right = np.searchsorted(x_sort,right)
    p_right[p_right>=y.shape[0]] = y.shape[0]-1
    p_left[p_left>=y.shape[0]] = y.shape[0]-1
    return (y[p_right]-y[p_left])

def get_pdf(tr,col,x_query=None,smooth=3):
    std = tr[col].std()
    tr = tr.dropna(subset=[col])
    df = tr.groupby(col).agg({'target':['sum','count']})
    cols = ['sum_y','count_y']
    df.columns = cols
    df = df.reset_index()
    df = df.sort_values(col)
    y,c = cols
    
    df[y] = df[y].cumsum()
    df[c] = df[c].cumsum()
    
    if x_query is None:
        rmin,rmax,res = -5.0, 5.0, 501
        x_query = np.linspace(rmin,rmax,res)
    
    dg = pd.DataFrame()
    tm = getp_vec_sum(x_query,df[col].values,df[y].values,std,c=smooth)
    cm = getp_vec_sum(x_query,df[col].values,df[c].values,std,c=smooth)+1
    dg['res'] = tm/cm
    dg.loc[cm<500,'res'] = 0.1
    return dg['res'].values

def get_pdfs(tr):
    y = []
    for i in range(200):
        name = 'var_%d'%i
        res = get_pdf(tr,name)
        y.append(res)
    return np.vstack(y)

def print_corr(corr_mat,col,bar=0.95):
    cols = corr_mat.loc[corr_mat[col]>bar,col].index.values
    return cols.tolist()

def get_group(df,cols,reverse=True,bar=0.9):
    if reverse:
        df = reverse(df,cols=cols)
    df = scale(df)
    pdfs = get_pdfs(df)
    df_pdf = pd.DataFrame(pdfs.T,columns=cols)
    corr_mat = df_pdf.corr(method='pearson')
    groups =[]
    skip_list = []
    for i in cols:
        if i not in skip_list:
            cols = print_corr(corr_mat,i,bar)
            if(len(cols)>1):
                groups.append(cols)
                for e,v in enumerate(cols):
                    skip_list.append(i)
    return groups

# %%
class DataGenerator(Sequence):
    'Generates data for Keras'
    def __init__(self, **kwargs):
        'Initialization'
        self.params = kwargs
        self.X = self.params['X']
        self.cols_info = self.params['cols_info']
        self.groups = self.params['groups']
        self.shuffle = self.params['shuffle']
        self.y = self.params['y']
        self.aug = self.params['aug']
        self.indexes = np.arange(self.y.shape[0])
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __len__(self):
        'Denotes the number of batches per epoch'
        batch_size = self.params['batch_size']
        return int(np.floor(self.indexes.shape[0] / batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        batch_size = self.params['batch_size']
        indexes = self.indexes[index*batch_size:(index+1)*batch_size]

        X, y = self.__data_generation(indexes)
        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, indexes):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        y = self.y[indexes]
        X = self.X[indexes]
        batch_size = self.params['batch_size']
        if self.aug:
            X,y = augment_fix_fast(X,y,groups=2,t1=2, t0=2)
        base_feats, noise_feats = self.cols_info
        allfeas = base_feats+noise_feats
        X = pd.DataFrame(X,columns=allfeas)
        X = get_keras_groups_data(X, self.cols_info,self.groups)
        return X, y
    
    def get_keras_data(self, dataset, cols_info):
        X = {}
        base_feats, noise_feats = cols_info
        X['base'] = np.reshape(dataset[:,:len(base_feats)], (-1, len(base_feats), 1))
        X['noise1'] = np.reshape(dataset[:,len(base_feats): len(base_feats) + len(noise_feats)], (-1, len(noise_feats), 1))
        
        return X
    
    def aug_(self,xb,xn1,y,t=2):
        xb_pos,xb_neg,xn1_pos,xn1_neg = [],[],[],[]
        for i in range(t):
            mask = y>0
            x1 = xb[mask].copy()
            x2 = xn1[mask].copy()
            ids = np.arange(x1.shape[0])
            for c in range(x1.shape[1]):
                np.random.shuffle(ids)
                x1[:,c] = x1[ids][:,c]
                x2[:,c] = x2[ids][:,c]
            xb_pos.append(x1)
            xn1_pos.append(x2)
        
        for i in range(t):
            mask = y==0
            x1 = xb[mask].copy()
            x2 = xn1[mask].copy()
            ids = np.arange(x1.shape[0])
            for c in range(x1.shape[1]):
                np.random.shuffle(ids)
                x1[:,c] = x1[ids][:,c]
                x2[:,c] = x2[ids][:,c]
            xb_neg.append(x1)
            xn1_neg.append(x2)
    

        xb_pos = np.vstack(xb_pos)
        xb_neg = np.vstack(xb_neg)
        xn1_pos = np.vstack(xn1_pos)
        xn1_neg = np.vstack(xn1_neg)

        ys = np.ones(xb_pos.shape[0])
        yn = np.zeros(xb_neg.shape[0])
        xb = np.vstack([xb,xb_pos,xb_neg])
        xn1 = np.vstack([xn1,xn1_pos,xn1_neg])
        y = np.concatenate([y,ys,yn])
        return xb,xn1,y

# %%
# define helper functions. auc, plot_history
def auc(y_true, y_pred):
    #auc = tf.metrics.auc(y_true, y_pred)[1]
    y_pred = y_pred.ravel()
    y_true = y_true.ravel()
    return roc_auc_score(y_true, y_pred)

def auc_2(y_true, y_pred):
    return tf.py_func(roc_auc_score, (y_true, y_pred), tf.double)

def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16,10))
    #plt.plot([0, 1], [0, 1], 'k--')
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key], '--', label=name.title()+' Val')

    plt.plot(history.epoch, history.history[key], color=val[0].get_color(), label=name.title()+' Train')

    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])
    plt.ylim([0, 0.4])
    plt.show()

# %%
def shuffle_col_vals_fix(x1, groups):
    group_size = x1.shape[1]//groups
    xs = [x1[:, i*group_size:(i+1)*group_size] for i in range(groups)]
    rand_x = np.array([np.random.choice(x1.shape[0], size=x1.shape[0], replace=False) for i in range(group_size)]).T
    grid = np.indices(xs[0].shape)
    rand_y = grid[1]
    res = [x[(rand_x, rand_y)] for x in xs]
    return np.hstack(res)

def augment_fix_fast(x,y,groups,t1=2, t0=2):
    # In order to make the sync version augment work, the df should be the form of:
    # var_1, var_2, var_3 | var_1_count, var_2_count, var_3_count | var_1_rolling, var_2_rolling, var_3_rolling
    # for the example above, 3 groups of feature, groups = 3
    xs,xn = [],[]
    for i in range(t1):
        mask = y>0
        x1 = x[mask].copy()
        x1 = shuffle_col_vals_fix(x1, groups)
        xs.append(x1)

    for i in range(t0):
        mask = (y==0)
        x1 = x[mask].copy()
        x1 = shuffle_col_vals_fix(x1, groups)
        xn.append(x1)

    xs = np.vstack(xs); xn = np.vstack(xn)
    ys = np.ones(xs.shape[0]);yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn]); y = np.concatenate([y,ys,yn])
    return x,y

# %%
def build_magic_nn():
    train_df = pd.read_csv('../input/train.csv')
    test_df =  pd.read_csv("../input/test.csv")

        
    base_features = [x for x in train_df.columns.values.tolist() if x.startswith('var_')]
    train_df['real'] = 1

    for col in base_features:
        test_df[col] = test_df[col].map(test_df[col].value_counts())
    a = test_df[base_features].min(axis=1)

    test_df = pd.read_csv('../input/test.csv')
    test_df['real'] = (a == 1).astype('int')

    train = train_df.append(test_df).reset_index(drop=True)
    del test_df, train_df; gc.collect()
    for col in tqdm(base_features):
        train[col + '_size'] = train[col].map(train.loc[train.real==1, col].value_counts())
    cnt_features = [col + '_size' for col in base_features]

    for col in tqdm(base_features):
    #        train[col+'size'] = train.groupby(col)['target'].transform('size')
        train.loc[train[col+'_size']>1,col+'_no_noise'] = train.loc[train[col+'_size']>1,col]
    noise1_features = [col + '_no_noise' for col in base_features]

    train[noise1_features] = train[noise1_features].fillna(train[noise1_features].mean())

    train_df = train[train['target'].notnull()]
    test_df = train[train['target'].isnull()]
    all_features = base_features + noise1_features

    scaler = preprocessing.StandardScaler().fit(train_df[all_features].values)
    df_trn = pd.DataFrame(scaler.transform(train_df[all_features].values), columns=all_features)
    df_tst = pd.DataFrame(scaler.transform(test_df[all_features].values), columns=all_features)

    return df_trn,df_tst,train_df,test_df

# %%
df_trn,df_tst,train_df,test_df = build_magic_nn()
# Out:
# 100%|██████████| 200/200 [00:09<00:00, 21.27it/s]
# 100%|██████████| 200/200 [04:13<00:00,  1.71s/it]

# %%
#%%time
y = train_df['target'].values
base_features = ['var_%d'%i for i in range(200)]
noise1_features = ['%s_no_noise'%i for i in base_features]
all_features = base_features + noise1_features
cols_info = [base_features, noise1_features]

# %%
df_trn = reverse(df_trn,cols=base_features + noise1_features)
df_tst = reverse(df_tst,cols=base_features + noise1_features)
# Out:
# reverse var_0
# reverse var_1
# reverse var_2
# reverse var_3
# reverse var_4
# reverse var_5
# reverse var_6
# reverse var_7
# reverse var_8
# reverse var_11
# reverse var_15
# reverse var_16
# reverse var_18
# reverse var_19
# reverse var_22
# reverse var_24
# reverse var_25
# reverse var_26
# reverse var_27
# reverse var_29
# reverse var_32
# reverse var_35
# reverse var_37
# reverse var_40
# reverse var_41
# reverse var_47
# reverse var_48
# reverse var_49
# reverse var_51
# reverse var_52
# reverse var_53
# reverse var_55
# reverse var_60
# reverse var_61
# reverse var_62
# reverse var_65
# reverse var_66
# reverse var_67
# reverse var_69
# reverse var_70
# reverse var_71
# reverse var_74
# reverse var_78
# reverse var_79
# reverse var_82
# reverse var_84
# reverse var_89
# reverse var_90
# reverse var_91
# reverse var_94
# reverse var_95
# reverse var_96
# reverse var_97
# reverse var_99
# reverse var_103
# reverse var_105
# reverse var_106
# reverse var_110
# reverse var_111
# reverse var_112
# reverse var_118
# reverse var_119
# reverse var_125
# reverse var_128
# reverse var_130
# reverse var_133
# reverse var_134
# reverse var_135
# reverse var_137
# reverse var_138
# reverse var_140
# reverse var_144
# reverse var_145
# reverse var_147
# reverse var_151
# reverse var_155
# reverse var_157
# reverse var_159
# reverse var_161
# reverse var_162
# reverse var_163
# reverse var_164
# reverse var_167
# reverse var_168
# reverse var_170
# reverse var_171
# reverse var_173
# reverse var_175
# reverse var_176
# reverse var_179
# reverse var_180
# reverse var_181
# reverse var_184
# reverse var_185
# reverse var_187
# reverse var_189
# reverse var_190
# reverse var_191
# reverse var_195
# reverse var_196
# reverse var_199
# reverse var_0_no_noise
# reverse var_1_no_noise
# reverse var_2_no_noise
# reverse var_3_no_noise
# reverse var_4_no_noise
# reverse var_5_no_noise
# reverse var_6_no_noise
# reverse var_7_no_noise
# reverse var_8_no_noise
# reverse var_11_no_noise
# reverse var_15_no_noise
# reverse var_16_no_noise
# reverse var_18_no_noise
# reverse var_19_no_noise
# reverse var_22_no_noise
# reverse var_24_no_noise
# reverse var_25_no_noise
# reverse var_26_no_noise
# reverse var_27_no_noise
# reverse var_29_no_noise
# reverse var_32_no_noise
# reverse var_35_no_noise
# reverse var_37_no_noise
# reverse var_40_no_noise
# reverse var_41_no_noise
# reverse var_47_no_noise
# reverse var_48_no_noise
# reverse var_49_no_noise
# reverse var_51_no_noise
# reverse var_52_no_noise
# reverse var_53_no_noise
# reverse var_55_no_noise
# reverse var_60_no_noise
# reverse var_61_no_noise
# reverse var_62_no_noise
# reverse var_65_no_noise
# reverse var_66_no_noise
# reverse var_67_no_noise
# reverse var_69_no_noise
# reverse var_70_no_noise
# reverse var_71_no_noise
# reverse var_74_no_noise
# reverse var_78_no_noise
# reverse var_79_no_noise
# reverse var_82_no_noise
# reverse var_84_no_noise
# reverse var_89_no_noise
# reverse var_90_no_noise
# reverse var_91_no_noise
# reverse var_94_no_noise
# reverse var_95_no_noise
# reverse var_96_no_noise
# reverse var_97_no_noise
# reverse var_99_no_noise
# reverse var_103_no_noise
# reverse var_105_no_noise
# reverse var_106_no_noise
# reverse var_110_no_noise
# reverse var_111_no_noise
# reverse var_112_no_noise
# reverse var_118_no_noise
# reverse var_119_no_noise
# reverse var_125_no_noise
# reverse var_128_no_noise
# reverse var_130_no_noise
# reverse var_133_no_noise
# reverse var_134_no_noise
# reverse var_135_no_noise
# reverse var_137_no_noise
# reverse var_138_no_noise
# reverse var_140_no_noise
# reverse var_144_no_noise
# reverse var_145_no_noise
# reverse var_147_no_noise
# reverse var_151_no_noise
# reverse var_155_no_noise
# reverse var_157_no_noise
# reverse var_159_no_noise
# reverse var_161_no_noise
# reverse var_162_no_noise
# reverse var_163_no_noise
# reverse var_164_no_noise
# reverse var_167_no_noise
# reverse var_168_no_noise
# reverse var_170_no_noise
# reverse var_171_no_noise
# reverse var_173_no_noise
# reverse var_175_no_noise
# reverse var_176_no_noise
# reverse var_179_no_noise
# reverse var_180_no_noise
# reverse var_181_no_noise
# reverse var_184_no_noise
# reverse var_185_no_noise
# reverse var_187_no_noise
# reverse var_189_no_noise
# reverse var_190_no_noise
# reverse var_191_no_noise
# reverse var_195_no_noise
# reverse var_196_no_noise
# reverse var_199_no_noise
# reverse var_0
# reverse var_1
# reverse var_2
# reverse var_3
# reverse var_4
# reverse var_5
# reverse var_6
# reverse var_7
# reverse var_8
# reverse var_11
# reverse var_15
# reverse var_16
# reverse var_18
# reverse var_19
# reverse var_22
# reverse var_24
# reverse var_25
# reverse var_26
# reverse var_27
# reverse var_29
# reverse var_32
# reverse var_35
# reverse var_37
# reverse var_40
# reverse var_41
# reverse var_47
# reverse var_48
# reverse var_49
# reverse var_51
# reverse var_52
# reverse var_53
# reverse var_55
# reverse var_60
# reverse var_61
# reverse var_62
# reverse var_65
# reverse var_66
# reverse var_67
# reverse var_69
# reverse var_70
# reverse var_71
# reverse var_74
# reverse var_78
# reverse var_79
# reverse var_82
# reverse var_84
# reverse var_89
# reverse var_90
# reverse var_91
# reverse var_94
# reverse var_95
# reverse var_96
# reverse var_97
# reverse var_99
# reverse var_103
# reverse var_105
# reverse var_106
# reverse var_110
# reverse var_111
# reverse var_112
# reverse var_118
# reverse var_119
# reverse var_125
# reverse var_128
# reverse var_130
# reverse var_133
# reverse var_134
# reverse var_135
# reverse var_137
# reverse var_138
# reverse var_140
# reverse var_144
# reverse var_145
# reverse var_147
# reverse var_151
# reverse var_155
# reverse var_157
# reverse var_159
# reverse var_161
# reverse var_162
# reverse var_163
# reverse var_164
# reverse var_167
# reverse var_168
# reverse var_170
# reverse var_171
# reverse var_173
# reverse var_175
# reverse var_176
# reverse var_179
# reverse var_180
# reverse var_181
# reverse var_184
# reverse var_185
# reverse var_187
# reverse var_189
# reverse var_190
# reverse var_191
# reverse var_195
# reverse var_196
# reverse var_199
# reverse var_0_no_noise
# reverse var_1_no_noise
# reverse var_2_no_noise
# reverse var_3_no_noise
# reverse var_4_no_noise
# reverse var_5_no_noise
# reverse var_6_no_noise
# reverse var_7_no_noise
# reverse var_8_no_noise
# reverse var_11_no_noise
# reverse var_15_no_noise
# reverse var_16_no_noise
# reverse var_18_no_noise
# reverse var_19_no_noise
# reverse var_22_no_noise
# reverse var_24_no_noise
# reverse var_25_no_noise
# reverse var_26_no_noise
# reverse var_27_no_noise
# reverse var_29_no_noise
# reverse var_32_no_noise
# reverse var_35_no_noise
# reverse var_37_no_noise
# reverse var_40_no_noise
# reverse var_41_no_noise
# reverse var_47_no_noise
# reverse var_48_no_noise
# reverse var_49_no_noise
# reverse var_51_no_noise
# reverse var_52_no_noise
# reverse var_53_no_noise
# reverse var_55_no_noise
# reverse var_60_no_noise
# reverse var_61_no_noise
# reverse var_62_no_noise
# reverse var_65_no_noise
# reverse var_66_no_noise
# reverse var_67_no_noise
# reverse var_69_no_noise
# reverse var_70_no_noise
# reverse var_71_no_noise
# reverse var_74_no_noise
# reverse var_78_no_noise
# reverse var_79_no_noise
# reverse var_82_no_noise
# reverse var_84_no_noise
# reverse var_89_no_noise
# reverse var_90_no_noise
# reverse var_91_no_noise
# reverse var_94_no_noise
# reverse var_95_no_noise
# reverse var_96_no_noise
# reverse var_97_no_noise
# reverse var_99_no_noise
# reverse var_103_no_noise
# reverse var_105_no_noise
# reverse var_106_no_noise
# reverse var_110_no_noise
# reverse var_111_no_noise
# reverse var_112_no_noise
# reverse var_118_no_noise
# reverse var_119_no_noise
# reverse var_125_no_noise
# reverse var_128_no_noise
# reverse var_130_no_noise
# reverse var_133_no_noise
# reverse var_134_no_noise
# reverse var_135_no_noise
# reverse var_137_no_noise
# reverse var_138_no_noise
# reverse var_140_no_noise
# reverse var_144_no_noise
# reverse var_145_no_noise
# reverse var_147_no_noise
# reverse var_151_no_noise
# reverse var_155_no_noise
# reverse var_157_no_noise
# reverse var_159_no_noise
# reverse var_161_no_noise
# reverse var_162_no_noise
# reverse var_163_no_noise
# reverse var_164_no_noise
# reverse var_167_no_noise
# reverse var_168_no_noise
# reverse var_170_no_noise
# reverse var_171_no_noise
# reverse var_173_no_noise
# reverse var_175_no_noise
# reverse var_176_no_noise
# reverse var_179_no_noise
# reverse var_180_no_noise
# reverse var_181_no_noise
# reverse var_184_no_noise
# reverse var_185_no_noise
# reverse var_187_no_noise
# reverse var_189_no_noise
# reverse var_190_no_noise
# reverse var_191_no_noise
# reverse var_195_no_noise
# reverse var_196_no_noise
# reverse var_199_no_noise

# %%
def get_keras_data(dataset, cols_info):
    X = {}
    base_feats, noise_feats = cols_info
    X['base'] = np.reshape(np.array(dataset[base_feats].values), (-1, len(base_feats), 1))
    X['noise1'] = np.reshape(np.array(dataset[noise_feats].values), (-1, len(noise_feats), 1))
    return X

def get_keras_groups_data(dataset, cols_info, groups):
    X = {}
    base_feats, noise_feats = cols_info
    #X['base'] = np.reshape(np.array(dataset[base_feats].values), (-1, len(base_feats), 1))
    for c,g in enumerate(groups):
        X['group_%d'%c] = np.expand_dims(dataset[g].values,2)
    X['noise1'] = np.expand_dims(dataset[noise_feats].values,2)
    return X

# %%
groups = get_group(train_df[base_features+['target']].copy(),base_features,reverse=False,bar=0.9)

# %%
X_test = get_keras_groups_data(df_tst[all_features], cols_info, groups)

# %%
# define network structure -> 2D CNN
def Convnet(cols_info, groups, classes=1):
    base_feats, noise1_feats= cols_info
    
    xs = []
    ins = []
    for c,i in enumerate(groups):
        X = Input(shape=(len(i), 1), name='group_%d'%c)
        ins.append(X)
        X = Dense(1)(X)
        X = Activation('relu')(X)
        X = Flatten(name='group_%d_last'%c)(X)
        xs.append(X)
    
    for i,j in zip(cols_info,['noise1']):
        X = Input(shape=(len(i), 1), name=j)
        ins.append(X)
        X = Dense(16)(X)
        X = Activation('relu')(X)
        X = Flatten(name='%s_last'%j)(X)
        xs.append(X)
    
    X = concatenate(xs)
    X = Dense(classes, activation='sigmoid')(X)
    
    model = Model(inputs=ins,outputs=X)
    return model

model = Convnet(cols_info,groups)
model.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# group_0 (InputLayer)            (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_1 (InputLayer)            (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_2 (InputLayer)            (None, 24, 1)        0
# __________________________________________________________________________________________________
# group_3 (InputLayer)            (None, 9, 1)         0
# __________________________________________________________________________________________________
# group_4 (InputLayer)            (None, 11, 1)        0
# __________________________________________________________________________________________________
# group_5 (InputLayer)            (None, 34, 1)        0
# __________________________________________________________________________________________________
# group_6 (InputLayer)            (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_7 (InputLayer)            (None, 29, 1)        0
# __________________________________________________________________________________________________
# group_8 (InputLayer)            (None, 18, 1)        0
# __________________________________________________________________________________________________
# group_9 (InputLayer)            (None, 39, 1)        0
# __________________________________________________________________________________________________
# group_10 (InputLayer)           (None, 28, 1)        0
# __________________________________________________________________________________________________
# group_11 (InputLayer)           (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_12 (InputLayer)           (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_13 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_14 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_15 (InputLayer)           (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_16 (InputLayer)           (None, 35, 1)        0
# __________________________________________________________________________________________________
# group_17 (InputLayer)           (None, 15, 1)        0
# __________________________________________________________________________________________________
# group_18 (InputLayer)           (None, 29, 1)        0
# __________________________________________________________________________________________________
# group_19 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_20 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_21 (InputLayer)           (None, 41, 1)        0
# __________________________________________________________________________________________________
# group_22 (InputLayer)           (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_23 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_24 (InputLayer)           (None, 29, 1)        0
# __________________________________________________________________________________________________
# group_25 (InputLayer)           (None, 27, 1)        0
# __________________________________________________________________________________________________
# group_26 (InputLayer)           (None, 34, 1)        0
# __________________________________________________________________________________________________
# group_27 (InputLayer)           (None, 20, 1)        0
# __________________________________________________________________________________________________
# group_28 (InputLayer)           (None, 34, 1)        0
# __________________________________________________________________________________________________
# group_29 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_30 (InputLayer)           (None, 6, 1)         0
# __________________________________________________________________________________________________
# group_31 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_32 (InputLayer)           (None, 28, 1)        0
# __________________________________________________________________________________________________
# group_33 (InputLayer)           (None, 18, 1)        0
# __________________________________________________________________________________________________
# group_34 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_35 (InputLayer)           (None, 23, 1)        0
# __________________________________________________________________________________________________
# group_36 (InputLayer)           (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_37 (InputLayer)           (None, 26, 1)        0
# __________________________________________________________________________________________________
# group_38 (InputLayer)           (None, 19, 1)        0
# __________________________________________________________________________________________________
# group_39 (InputLayer)           (None, 10, 1)        0
# __________________________________________________________________________________________________
# group_40 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_41 (InputLayer)           (None, 16, 1)        0
# __________________________________________________________________________________________________
# group_42 (InputLayer)           (None, 9, 1)         0
# __________________________________________________________________________________________________
# group_43 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_44 (InputLayer)           (None, 8, 1)         0
# __________________________________________________________________________________________________
# group_45 (InputLayer)           (None, 8, 1)         0
# __________________________________________________________________________________________________
# group_46 (InputLayer)           (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_47 (InputLayer)           (None, 7, 1)         0
# __________________________________________________________________________________________________
# group_48 (InputLayer)           (None, 8, 1)         0
# __________________________________________________________________________________________________
# group_49 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_50 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_51 (InputLayer)           (None, 26, 1)        0
# __________________________________________________________________________________________________
# group_52 (InputLayer)           (None, 21, 1)        0
# __________________________________________________________________________________________________
# group_53 (InputLayer)           (None, 11, 1)        0
# __________________________________________________________________________________________________
# group_54 (InputLayer)           (None, 20, 1)        0
# __________________________________________________________________________________________________
# group_55 (InputLayer)           (None, 40, 1)        0
# __________________________________________________________________________________________________
# group_56 (InputLayer)           (None, 10, 1)        0
# __________________________________________________________________________________________________
# group_57 (InputLayer)           (None, 34, 1)        0
# __________________________________________________________________________________________________
# group_58 (InputLayer)           (None, 16, 1)        0
# __________________________________________________________________________________________________
# group_59 (InputLayer)           (None, 2, 1)         0
# __________________________________________________________________________________________________
# group_60 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_61 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_62 (InputLayer)           (None, 16, 1)        0
# __________________________________________________________________________________________________
# group_63 (InputLayer)           (None, 37, 1)        0
# __________________________________________________________________________________________________
# group_64 (InputLayer)           (None, 11, 1)        0
# __________________________________________________________________________________________________
# group_65 (InputLayer)           (None, 24, 1)        0
# __________________________________________________________________________________________________
# group_66 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_67 (InputLayer)           (None, 13, 1)        0
# __________________________________________________________________________________________________
# group_68 (InputLayer)           (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_69 (InputLayer)           (None, 9, 1)         0
# __________________________________________________________________________________________________
# group_70 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_71 (InputLayer)           (None, 46, 1)        0
# __________________________________________________________________________________________________
# group_72 (InputLayer)           (None, 17, 1)        0
# __________________________________________________________________________________________________
# group_73 (InputLayer)           (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_74 (InputLayer)           (None, 24, 1)        0
# __________________________________________________________________________________________________
# group_75 (InputLayer)           (None, 2, 1)         0
# __________________________________________________________________________________________________
# group_76 (InputLayer)           (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_77 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_78 (InputLayer)           (None, 13, 1)        0
# __________________________________________________________________________________________________
# group_79 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_80 (InputLayer)           (None, 44, 1)        0
# __________________________________________________________________________________________________
# group_81 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_82 (InputLayer)           (None, 11, 1)        0
# __________________________________________________________________________________________________
# group_83 (InputLayer)           (None, 4, 1)         0
# __________________________________________________________________________________________________
# group_84 (InputLayer)           (None, 16, 1)        0
# __________________________________________________________________________________________________
# group_85 (InputLayer)           (None, 43, 1)        0
# __________________________________________________________________________________________________
# group_86 (InputLayer)           (None, 25, 1)        0
# __________________________________________________________________________________________________
# group_87 (InputLayer)           (None, 20, 1)        0
# __________________________________________________________________________________________________
# group_88 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_89 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_90 (InputLayer)           (None, 31, 1)        0
# __________________________________________________________________________________________________
# group_91 (InputLayer)           (None, 2, 1)         0
# __________________________________________________________________________________________________
# group_92 (InputLayer)           (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_93 (InputLayer)           (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_94 (InputLayer)           (None, 35, 1)        0
# __________________________________________________________________________________________________
# group_95 (InputLayer)           (None, 25, 1)        0
# __________________________________________________________________________________________________
# group_96 (InputLayer)           (None, 25, 1)        0
# __________________________________________________________________________________________________
# group_97 (InputLayer)           (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_98 (InputLayer)           (None, 23, 1)        0
# __________________________________________________________________________________________________
# group_99 (InputLayer)           (None, 38, 1)        0
# __________________________________________________________________________________________________
# group_100 (InputLayer)          (None, 36, 1)        0
# __________________________________________________________________________________________________
# group_101 (InputLayer)          (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_102 (InputLayer)          (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_103 (InputLayer)          (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_104 (InputLayer)          (None, 29, 1)        0
# __________________________________________________________________________________________________
# group_105 (InputLayer)          (None, 33, 1)        0
# __________________________________________________________________________________________________
# group_106 (InputLayer)          (None, 26, 1)        0
# __________________________________________________________________________________________________
# group_107 (InputLayer)          (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_108 (InputLayer)          (None, 18, 1)        0
# __________________________________________________________________________________________________
# group_109 (InputLayer)          (None, 35, 1)        0
# __________________________________________________________________________________________________
# group_110 (InputLayer)          (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_111 (InputLayer)          (None, 34, 1)        0
# __________________________________________________________________________________________________
# group_112 (InputLayer)          (None, 39, 1)        0
# __________________________________________________________________________________________________
# group_113 (InputLayer)          (None, 26, 1)        0
# __________________________________________________________________________________________________
# group_114 (InputLayer)          (None, 9, 1)         0
# __________________________________________________________________________________________________
# group_115 (InputLayer)          (None, 23, 1)        0
# __________________________________________________________________________________________________
# group_116 (InputLayer)          (None, 16, 1)        0
# __________________________________________________________________________________________________
# group_117 (InputLayer)          (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_118 (InputLayer)          (None, 9, 1)         0
# __________________________________________________________________________________________________
# group_119 (InputLayer)          (None, 39, 1)        0
# __________________________________________________________________________________________________
# group_120 (InputLayer)          (None, 39, 1)        0
# __________________________________________________________________________________________________
# group_121 (InputLayer)          (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_122 (InputLayer)          (None, 6, 1)         0
# __________________________________________________________________________________________________
# group_123 (InputLayer)          (None, 30, 1)        0
# __________________________________________________________________________________________________
# group_124 (InputLayer)          (None, 7, 1)         0
# __________________________________________________________________________________________________
# group_125 (InputLayer)          (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_126 (InputLayer)          (None, 28, 1)        0
# __________________________________________________________________________________________________
# group_127 (InputLayer)          (None, 13, 1)        0
# __________________________________________________________________________________________________
# group_128 (InputLayer)          (None, 38, 1)        0
# __________________________________________________________________________________________________
# group_129 (InputLayer)          (None, 40, 1)        0
# __________________________________________________________________________________________________
# group_130 (InputLayer)          (None, 14, 1)        0
# __________________________________________________________________________________________________
# group_131 (InputLayer)          (None, 11, 1)        0
# __________________________________________________________________________________________________
# group_132 (InputLayer)          (None, 37, 1)        0
# __________________________________________________________________________________________________
# group_133 (InputLayer)          (None, 33, 1)        0
# __________________________________________________________________________________________________
# group_134 (InputLayer)          (None, 19, 1)        0
# __________________________________________________________________________________________________
# group_135 (InputLayer)          (None, 7, 1)         0
# __________________________________________________________________________________________________
# group_136 (InputLayer)          (None, 32, 1)        0
# __________________________________________________________________________________________________
# group_137 (InputLayer)          (None, 13, 1)        0
# __________________________________________________________________________________________________
# group_138 (InputLayer)          (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_139 (InputLayer)          (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_140 (InputLayer)          (None, 15, 1)        0
# __________________________________________________________________________________________________
# group_141 (InputLayer)          (None, 22, 1)        0
# __________________________________________________________________________________________________
# group_142 (InputLayer)          (None, 28, 1)        0
# __________________________________________________________________________________________________
# group_143 (InputLayer)          (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_144 (InputLayer)          (None, 18, 1)        0
# __________________________________________________________________________________________________
# group_145 (InputLayer)          (None, 5, 1)         0
# __________________________________________________________________________________________________
# group_146 (InputLayer)          (None, 28, 1)        0
# __________________________________________________________________________________________________
# group_147 (InputLayer)          (None, 19, 1)        0
# __________________________________________________________________________________________________
# group_148 (InputLayer)          (None, 21, 1)        0
# __________________________________________________________________________________________________
# group_149 (InputLayer)          (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_150 (InputLayer)          (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_151 (InputLayer)          (None, 15, 1)        0
# __________________________________________________________________________________________________
# group_152 (InputLayer)          (None, 2, 1)         0
# __________________________________________________________________________________________________
# group_153 (InputLayer)          (None, 45, 1)        0
# __________________________________________________________________________________________________
# group_154 (InputLayer)          (None, 19, 1)        0
# __________________________________________________________________________________________________
# group_155 (InputLayer)          (None, 3, 1)         0
# __________________________________________________________________________________________________
# group_156 (InputLayer)          (None, 7, 1)         0
# __________________________________________________________________________________________________
# group_157 (InputLayer)          (None, 10, 1)        0
# __________________________________________________________________________________________________
# group_158 (InputLayer)          (None, 33, 1)        0
# __________________________________________________________________________________________________
# group_159 (InputLayer)          (None, 12, 1)        0
# __________________________________________________________________________________________________
# group_160 (InputLayer)          (None, 27, 1)        0
# __________________________________________________________________________________________________
# group_161 (InputLayer)          (None, 21, 1)        0
# __________________________________________________________________________________________________
# group_162 (InputLayer)          (None, 2, 1)         0
# __________________________________________________________________________________________________
# noise1 (InputLayer)             (None, 200, 1)       0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 36, 1)        2           group_0[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30, 1)        2           group_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 24, 1)        2           group_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 9, 1)         2           group_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 11, 1)        2           group_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 34, 1)        2           group_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 36, 1)        2           group_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 29, 1)        2           group_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 18, 1)        2           group_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 39, 1)        2           group_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 28, 1)        2           group_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 22, 1)        2           group_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 3, 1)         2           group_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 31, 1)        2           group_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 14, 1)        2           group_14[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 3, 1)         2           group_15[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 35, 1)        2           group_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 15, 1)        2           group_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 29, 1)        2           group_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 31, 1)        2           group_19[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 12, 1)        2           group_20[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 41, 1)        2           group_21[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 32, 1)        2           group_22[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 4, 1)         2           group_23[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 29, 1)        2           group_24[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 27, 1)        2           group_25[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 34, 1)        2           group_26[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 20, 1)        2           group_27[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 34, 1)        2           group_28[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 14, 1)        2           group_29[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 6, 1)         2           group_30[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 30, 1)        2           group_31[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 28, 1)        2           group_32[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 18, 1)        2           group_33[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 4, 1)         2           group_34[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 23, 1)        2           group_35[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 36, 1)        2           group_36[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 26, 1)        2           group_37[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 19, 1)        2           group_38[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 10, 1)        2           group_39[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 30, 1)        2           group_40[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 16, 1)        2           group_41[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 9, 1)         2           group_42[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 4, 1)         2           group_43[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 8, 1)         2           group_44[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 8, 1)         2           group_45[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 3, 1)         2           group_46[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 7, 1)         2           group_47[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 8, 1)         2           group_48[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 14, 1)        2           group_49[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 30, 1)        2           group_50[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 26, 1)        2           group_51[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 21, 1)        2           group_52[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 11, 1)        2           group_53[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 20, 1)        2           group_54[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 40, 1)        2           group_55[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 10, 1)        2           group_56[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 34, 1)        2           group_57[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 16, 1)        2           group_58[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 2, 1)         2           group_59[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 31, 1)        2           group_60[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 12, 1)        2           group_61[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 16, 1)        2           group_62[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 37, 1)        2           group_63[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 11, 1)        2           group_64[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 24, 1)        2           group_65[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 4, 1)         2           group_66[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 13, 1)        2           group_67[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 22, 1)        2           group_68[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 9, 1)         2           group_69[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 31, 1)        2           group_70[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 46, 1)        2           group_71[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 17, 1)        2           group_72[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 36, 1)        2           group_73[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 24, 1)        2           group_74[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  group_8_last[0][0]
#                                                                  group_9_last[0][0]
#                                                                  group_10_last[0][0]
#                                                                  group_11_last[0][0]
#                                                                  group_12_last[0][0]
#                                                                  group_13_last[0][0]
#                                                                  group_14_last[0][0]
#                                                                  group_15_last[0][0]
#                                                                  group_16_last[0][0]
#                                                                  group_17_last[0][0]
#                                                                  group_18_last[0][0]
#                                                                  group_19_last[0][0]
#                                                                  group_20_last[0][0]
#                                                                  group_21_last[0][0]
#                                                                  group_22_last[0][0]
#                                                                  group_23_last[0][0]
#                                                                  group_24_last[0][0]
#                                                                  group_25_last[0][0]
#                                                                  group_26_last[0][0]
#                                                                  group_27_last[0][0]
#                                                                  group_28_last[0][0]
#                                                                  group_29_last[0][0]
#                                                                  group_30_last[0][0]
#                                                                  group_31_last[0][0]
#                                                                  group_32_last[0][0]
#                                                                  group_33_last[0][0]
#                                                                  group_34_last[0][0]
#                                                                  group_35_last[0][0]
#                                                                  group_36_last[0][0]
#                                                                  group_37_last[0][0]
#                                                                  group_38_last[0][0]
#                                                                  group_39_last[0][0]
#                                                                  group_40_last[0][0]
#                                                                  group_41_last[0][0]
#                                                                  group_42_last[0][0]
#                                                                  group_43_last[0][0]
#                                                                  group_44_last[0][0]
#                                                                  group_45_last[0][0]
#                                                                  group_46_last[0][0]
#                                                                  group_47_last[0][0]
#                                                                  group_48_last[0][0]
#                                                                  group_49_last[0][0]
#                                                                  group_50_last[0][0]
#                                                                  group_51_last[0][0]
#                                                                  group_52_last[0][0]
#                                                                  group_53_last[0][0]
#                                                                  group_54_last[0][0]
#                                                                  group_55_last[0][0]
#                                                                  group_56_last[0][0]
#                                                                  group_57_last[0][0]
#                                                                  group_58_last[0][0]
#                                                                  group_59_last[0][0]
#                                                                  group_60_last[0][0]
#                                                                  group_61_last[0][0]
#                                                                  group_62_last[0][0]
#                                                                  group_63_last[0][0]
#                                                                  group_64_last[0][0]
#                                                                  group_65_last[0][0]
#                                                                  group_66_last[0][0]
#                                                                  group_67_last[0][0]
#                                                                  group_68_last[0][0]
#                                                                  group_69_last[0][0]
#                                                                  group_70_last[0][0]
#                                                                  group_71_last[0][0]
#                                                                  group_72_last[0][0]
#                                                                  group_73_last[0][0]
#                                                                  group_74_last[0][0]
#                                                                  group_75_last[0][0]
#                                                                  group_76_last[0][0]
#                                                                  group_77_last[0][0]
#                                                                  group_78_last[0][0]
#                                                                  group_79_last[0][0]
#                                                                  group_80_last[0][0]
#                                                                  group_81_last[0][0]
#                                                                  group_82_last[0][0]
#                                                                  group_83_last[0][0]
#                                                                  group_84_last[0][0]
#                                                                  group_85_last[0][0]
#                                                                  group_86_last[0][0]
#                                                                  group_87_last[0][0]
#                                                                  group_88_last[0][0]
#                                                                  group_89_last[0][0]
#                                                                  group_90_last[0][0]
#                                                                  group_91_last[0][0]
#                                                                  group_92_last[0][0]
#                                                                  group_93_last[0][0]
#                                                                  group_94_last[0][0]
#                                                                  group_95_last[0][0]
#                                                                  group_96_last[0][0]
#                                                                  group_97_last[0][0]
#                                                                  group_98_last[0][0]
#                                                                  group_99_last[0][0]
#                                                                  group_100_last[0][0]
#                                                                  group_101_last[0][0]
#                                                                  group_102_last[0][0]
#                                                                  group_103_last[0][0]
#                                                                  group_104_last[0][0]
#                                                                  group_105_last[0][0]
#                                                                  group_106_last[0][0]
#                                                                  group_107_last[0][0]
#                                                                  group_108_last[0][0]
#                                                                  group_109_last[0][0]
#                                                                  group_110_last[0][0]
#                                                                  group_111_last[0][0]
#                                                                  group_112_last[0][0]
#                                                                  group_113_last[0][0]
#                                                                  group_114_last[0][0]
#                                                                  group_115_last[0][0]
#                                                                  group_116_last[0][0]
#                                                                  group_117_last[0][0]
#                                                                  group_118_last[0][0]
#                                                                  group_119_last[0][0]
#                                                                  group_120_last[0][0]
#                                                                  group_121_last[0][0]
#                                                                  group_122_last[0][0]
#                                                                  group_123_last[0][0]
#                                                                  group_124_last[0][0]
#                                                                  group_125_last[0][0]
#                                                                  group_126_last[0][0]
#                                                                  group_127_last[0][0]
#                                                                  group_128_last[0][0]
#                                                                  group_129_last[0][0]
#                                                                  group_130_last[0][0]
#                                                                  group_131_last[0][0]
#                                                                  group_132_last[0][0]
#                                                                  group_133_last[0][0]
#                                                                  group_134_last[0][0]
#                                                                  group_135_last[0][0]
#                                                                  group_136_last[0][0]
#                                                                  group_137_last[0][0]
#                                                                  group_138_last[0][0]
#                                                                  group_139_last[0][0]
#                                                                  group_140_last[0][0]
#                                                                  group_141_last[0][0]
#                                                                  group_142_last[0][0]
#                                                                  group_143_last[0][0]
#                                                                  group_144_last[0][0]
#                                                                  group_145_last[0][0]
#                                                                  group_146_last[0][0]
#                                                                  group_147_last[0][0]
#                                                                  group_148_last[0][0]
#                                                                  group_149_last[0][0]
#                                                                  group_150_last[0][0]
#                                                                  group_151_last[0][0]
#                                                                  group_152_last[0][0]
#                                                                  group_153_last[0][0]
#                                                                  group_154_last[0][0]
#                                                                  group_155_last[0][0]
#                                                                  group_156_last[0][0]
#                                                                  group_157_last[0][0]
#                                                                  group_158_last[0][0]
#                                                                  group_159_last[0][0]
#                                                                  group_160_last[0][0]
#                                                                  group_161_last[0][0]
#                                                                  group_162_last[0][0]
#                                                                  noise1_last[0][0]
# __________________________________________________________________________________________________
# dense_165 (Dense)               (None, 1)            6694        concatenate_1[0][0]
# ==================================================================================================
# Total params: 7,052
# Trainable params: 7,052
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
try:
    del train, df_tst 
except:
    pass
gc.collect()
# Out:
# 0

# %%
# parameters
SEED = 2019
n_folds = 5
debug_flag = True
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=SEED)

# %%
#%%time
#transformed_shape = tuple([-1] + list(shape))
#X_test = np.reshape(X_test, transformed_shape)

i = 0
result = pd.DataFrame({"ID_code": test_df.ID_code.values})
val_aucs = []
valid_X = train_df[['target']]
valid_X['predict'] = 0
for train_idx, val_idx in skf.split(df_trn, y):
    if i == RUN_FOLDS:
        break
    
    i += 1    
    X_train, y_train = df_trn.iloc[train_idx], y[train_idx]
    X_valid, y_valid = df_trn.iloc[val_idx], y[val_idx]
    
    #aug
    X_train, y_train = augment_fix_fast(X_train.values, y_train, groups=2, t1=2, t0=2)
    X_train = pd.DataFrame(X_train, columns=all_features)
    
    #X_train = get_keras_data(X_train, cols_info)
    #X_valid = get_keras_data(X_valid, cols_info)
    #X_train = np.reshape(X_train, transformed_shape)
    #X_valid = np.reshape(X_valid, transformed_shape)
    
    model_name = 'NN_fold{}_{}.h5'.format(str(i),GPU)
    
    model = Convnet(cols_info,groups)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'binary_crossentropy', auc_2])
    checkpoint = ModelCheckpoint(model_name, monitor='val_auc_2', verbose=1, 
                                 save_best_only=True, mode='max', save_weights_only = True)
    reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=4, 
                                       verbose=1, mode='min', epsilon=0.0001)
    earlystop = EarlyStopping(monitor='val_auc_2', mode='max', patience=5, verbose=1)
    
    if 1:
        training_generator = DataGenerator(X=X_train.values,y=y_train,aug=1,groups=groups,
                                           batch_size=BATCHSIZE,shuffle=True,cols_info=cols_info)
        
        validation_generator = DataGenerator(X=X_valid.values,y=y_valid,aug=0,groups=groups,
                                             batch_size=BATCHSIZE,shuffle=False,cols_info=cols_info)
        
        history = model.fit_generator(generator=training_generator,
                        validation_data=validation_generator,
                        epochs=EPOCHS,  
                        callbacks=[checkpoint, reduceLROnPlat, earlystop])
    train_history = pd.DataFrame(history.history)
    train_history.to_csv('train_profile_fold{}_{}.csv'.format(str(i),GPU), index=None)
    
    # load and predict
    model.load_weights(model_name)
    
    #predict
    X_valid = get_keras_groups_data(X_valid, cols_info,groups)
    y_pred_keras = model.predict(X_valid).ravel()
    
    # AUC
    valid_X['predict'].iloc[val_idx] = y_pred_keras
    
    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_valid, y_pred_keras)
    auc_valid = roc_auc_score(y_valid, y_pred_keras)
    val_aucs.append(auc_valid)
    print('Fold %d auc %.4f'%(i,val_aucs[-1]))
    prediction = model.predict(X_test)
    result["fold{}".format(str(i))] = prediction
# Out:
# WARNING:tensorflow:From <ipython-input-5-4c2cc91224d8>:9: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 3749/3749 [==============================] - 864s 230ms/step - loss: 0.2097 - acc: 0.9230 - binary_crossentropy: 0.2097 - auc_2: 0.8910 - val_loss: 0.1974 - val_acc: 0.9275 - val_binary_crossentropy: 0.1974 - val_auc_2: 0.9134
#
# Epoch 00001: val_auc_2 improved from -inf to 0.91344, saving model to NN_fold1_4.h5
# Fold 1 auc 0.9136

# %%
for i in range(len(val_aucs)):
    print('Fold_%d AUC: %.6f' % (i+1, val_aucs[i]))
# Out:
# Fold_1 AUC: 0.913555

# %%
val_aucs
# Out:
# [0.9135547769061642]

# %%
# summary on results
auc_mean = np.mean(val_aucs)
auc_std = np.std(val_aucs)
auc_all = roc_auc_score(valid_X.target, valid_X.predict)
print('%d-fold auc mean: %.9f, std: %.9f. All auc: %6f.' % (n_folds, auc_mean, auc_std, auc_all))
# Out:
# 5-fold auc mean: 0.913554777, std: 0.000000000. All auc: 0.516552.

# %%
y_all = result.values[:, 1:]
result['target'] = np.mean(y_all, axis = 1)
to_submit = result[['ID_code', 'target']]
to_submit.to_csv('NN_submission_{}.csv'.format(GPU), index=None)
result.to_csv('NN_all_prediction_{}.csv'.format(GPU), index=None)
valid_X['ID_code'] = train_df['ID_code']
valid_X = valid_X[['ID_code', 'target', 'predict']].to_csv('NN_oof_{}.csv'.format(GPU), index=None)
