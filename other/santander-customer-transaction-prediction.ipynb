# %%
# Data manipulation and set-up
import numpy as np
import pandas as pd

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1)

# Modelling (including set-up & evaluation)
from sklearn.model_selection import KFold, StratifiedKFold
import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import roc_auc_score

# Ignore warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
random_state = 42
np.random.seed(random_state)
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
# Data augmentation
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
# Model parameters
lgb_params = {
    "objective" : "binary",
    "metric" : "auc",
    "boosting": 'gbdt',
    "max_depth" : -1,
    "num_leaves" : 31,
    "learning_rate" : 0.01,
    "bagging_freq": 5,
    "bagging_fraction" : 0.4,
    "feature_fraction" : 0.05,
    "min_data_in_leaf": 150,
    "min_sum_heassian_in_leaf": 10,
    "tree_learner": "serial",
    "boost_from_average": "false",
    "bagging_seed" : random_state,
    "verbosity" : 1,
    "seed": random_state}

# %%
skf = StratifiedKFold(n_splits=7, shuffle=True, random_state=random_state)
oof = train[['ID_code', 'target']]
oof['predict'] = 0
predictions = test[['ID_code']]
val_aucs = []
feature_importance = pd.DataFrame()

# %%
features = [col for col in train.columns if col not in ['target', 'ID_code']]
X_test = test[features].values

# %%
for fold, (trn_idx, val_idx) in enumerate(skf.split(train, train['target'])):
    X_train, y_train = train.iloc[trn_idx][features], train.iloc[trn_idx]['target']
    X_valid, y_valid = train.iloc[val_idx][features], train.iloc[val_idx]['target']
    
    N = 3
    p_valid,yp = 0,0
    for i in range(N):
        X_t, y_t = augment(X_train.values, y_train.values)
        X_t = pd.DataFrame(X_t)
        X_t = X_t.add_prefix('var_')
    
        trn_data = lgb.Dataset(X_t, label=y_t)
        val_data = lgb.Dataset(X_valid, label=y_valid)
        evals_result = {}
        lgb_clf = lgb.train(lgb_params,
                        trn_data,
                        100000,
                        valid_sets = [trn_data, val_data],
                        early_stopping_rounds=3000,
                        verbose_eval = 1000,
                        evals_result=evals_result
                       )
        p_valid += lgb_clf.predict(X_valid)
        yp += lgb_clf.predict(X_test)
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = features
    fold_importance["importance"] = lgb_clf.feature_importance()
    fold_importance["fold"] = fold + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
    oof['predict'][val_idx] = p_valid/N
    val_score = roc_auc_score(y_valid, p_valid)
    val_aucs.append(val_score)
    
    predictions['fold{}'.format(fold+1)] = yp/N
# Out:
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908775	valid_1's auc: 0.892624
# [2000]	training's auc: 0.91704	valid_1's auc: 0.897436
# [3000]	training's auc: 0.923209	valid_1's auc: 0.899713
# [4000]	training's auc: 0.92848	valid_1's auc: 0.900872
# [5000]	training's auc: 0.93321	valid_1's auc: 0.901501
# [6000]	training's auc: 0.937671	valid_1's auc: 0.901821
# [7000]	training's auc: 0.941879	valid_1's auc: 0.901806
# [8000]	training's auc: 0.94588	valid_1's auc: 0.901771
# [9000]	training's auc: 0.949656	valid_1's auc: 0.901779
# Early stopping, best iteration is:
# [6173]	training's auc: 0.938408	valid_1's auc: 0.901895
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907191	valid_1's auc: 0.89206
# [2000]	training's auc: 0.915736	valid_1's auc: 0.897656
# [3000]	training's auc: 0.921922	valid_1's auc: 0.899839
# [4000]	training's auc: 0.927245	valid_1's auc: 0.901311
# [5000]	training's auc: 0.932113	valid_1's auc: 0.901944
# [6000]	training's auc: 0.936634	valid_1's auc: 0.902375
# [7000]	training's auc: 0.94087	valid_1's auc: 0.90256
# [8000]	training's auc: 0.944899	valid_1's auc: 0.902614
# [9000]	training's auc: 0.948721	valid_1's auc: 0.902474
# [10000]	training's auc: 0.952439	valid_1's auc: 0.902227
# [11000]	training's auc: 0.955948	valid_1's auc: 0.902272
# Early stopping, best iteration is:
# [8247]	training's auc: 0.945851	valid_1's auc: 0.902654
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908637	valid_1's auc: 0.891604
# [2000]	training's auc: 0.916936	valid_1's auc: 0.896764
# [3000]	training's auc: 0.923123	valid_1's auc: 0.899423
# [4000]	training's auc: 0.928262	valid_1's auc: 0.900906
# [5000]	training's auc: 0.932997	valid_1's auc: 0.901665
# [6000]	training's auc: 0.937449	valid_1's auc: 0.901907
# [7000]	training's auc: 0.941611	valid_1's auc: 0.901891
# [8000]	training's auc: 0.945632	valid_1's auc: 0.901806
# [9000]	training's auc: 0.949418	valid_1's auc: 0.90169
# Early stopping, best iteration is:
# [6101]	training's auc: 0.937889	valid_1's auc: 0.901952
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908052	valid_1's auc: 0.888544
# [2000]	training's auc: 0.916461	valid_1's auc: 0.892674
# [3000]	training's auc: 0.922674	valid_1's auc: 0.895221
# [4000]	training's auc: 0.927914	valid_1's auc: 0.896564
# [5000]	training's auc: 0.932757	valid_1's auc: 0.897052
# [6000]	training's auc: 0.937204	valid_1's auc: 0.897185
# [7000]	training's auc: 0.941412	valid_1's auc: 0.897406
# [8000]	training's auc: 0.945429	valid_1's auc: 0.897333
# [9000]	training's auc: 0.94925	valid_1's auc: 0.897199
# [10000]	training's auc: 0.952878	valid_1's auc: 0.897094
# Early stopping, best iteration is:
# [7512]	training's auc: 0.94347	valid_1's auc: 0.897567
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908165	valid_1's auc: 0.888373
# [2000]	training's auc: 0.91655	valid_1's auc: 0.892712
# [3000]	training's auc: 0.922719	valid_1's auc: 0.895045
# [4000]	training's auc: 0.92801	valid_1's auc: 0.896249
# [5000]	training's auc: 0.932809	valid_1's auc: 0.896857
# [6000]	training's auc: 0.937304	valid_1's auc: 0.897342
# [7000]	training's auc: 0.941529	valid_1's auc: 0.897407
# [8000]	training's auc: 0.945521	valid_1's auc: 0.89736
# [9000]	training's auc: 0.949339	valid_1's auc: 0.897262
# Early stopping, best iteration is:
# [6252]	training's auc: 0.938408	valid_1's auc: 0.897479
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90859	valid_1's auc: 0.888876
# [2000]	training's auc: 0.916894	valid_1's auc: 0.893257
# [3000]	training's auc: 0.923135	valid_1's auc: 0.895567
# [4000]	training's auc: 0.928328	valid_1's auc: 0.896747
# [5000]	training's auc: 0.933131	valid_1's auc: 0.897256
# [6000]	training's auc: 0.937558	valid_1's auc: 0.89743
# [7000]	training's auc: 0.941798	valid_1's auc: 0.897482
# [8000]	training's auc: 0.945765	valid_1's auc: 0.897506
# [9000]	training's auc: 0.949567	valid_1's auc: 0.897327
# [10000]	training's auc: 0.95322	valid_1's auc: 0.897126
# Early stopping, best iteration is:
# [7815]	training's auc: 0.945047	valid_1's auc: 0.897569
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90789	valid_1's auc: 0.896032
# [2000]	training's auc: 0.916298	valid_1's auc: 0.900092
# [3000]	training's auc: 0.922479	valid_1's auc: 0.902359
# [4000]	training's auc: 0.927782	valid_1's auc: 0.903567
# [5000]	training's auc: 0.932618	valid_1's auc: 0.904063
# [6000]	training's auc: 0.937055	valid_1's auc: 0.90419
# [7000]	training's auc: 0.941274	valid_1's auc: 0.904188
# [8000]	training's auc: 0.945249	valid_1's auc: 0.904062
# [9000]	training's auc: 0.949087	valid_1's auc: 0.903752
# Early stopping, best iteration is:
# [6652]	training's auc: 0.939822	valid_1's auc: 0.904242
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90815	valid_1's auc: 0.895724
# [2000]	training's auc: 0.916706	valid_1's auc: 0.900307
# [3000]	training's auc: 0.922933	valid_1's auc: 0.902528
# [4000]	training's auc: 0.92822	valid_1's auc: 0.903755
# [5000]	training's auc: 0.932958	valid_1's auc: 0.904291
# [6000]	training's auc: 0.937449	valid_1's auc: 0.904435
# [7000]	training's auc: 0.941642	valid_1's auc: 0.90455
# [8000]	training's auc: 0.945616	valid_1's auc: 0.90445
# [9000]	training's auc: 0.949438	valid_1's auc: 0.904307
# Early stopping, best iteration is:
# [6746]	training's auc: 0.940609	valid_1's auc: 0.904601
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.9084	valid_1's auc: 0.895905
# [2000]	training's auc: 0.916778	valid_1's auc: 0.90024
# [3000]	training's auc: 0.92298	valid_1's auc: 0.902213
# [4000]	training's auc: 0.928313	valid_1's auc: 0.903659
# [5000]	training's auc: 0.933096	valid_1's auc: 0.904148
# [6000]	training's auc: 0.937532	valid_1's auc: 0.904349
# [7000]	training's auc: 0.941747	valid_1's auc: 0.904493
# [8000]	training's auc: 0.945739	valid_1's auc: 0.904387
# [9000]	training's auc: 0.949516	valid_1's auc: 0.904229
# Early stopping, best iteration is:
# [6952]	training's auc: 0.941552	valid_1's auc: 0.904509
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90726	valid_1's auc: 0.898038
# [2000]	training's auc: 0.915447	valid_1's auc: 0.903279
# [3000]	training's auc: 0.921653	valid_1's auc: 0.905648
# [4000]	training's auc: 0.92696	valid_1's auc: 0.907056
# [5000]	training's auc: 0.93182	valid_1's auc: 0.907949
# [6000]	training's auc: 0.936267	valid_1's auc: 0.908447
# [7000]	training's auc: 0.940522	valid_1's auc: 0.908606
# [8000]	training's auc: 0.944586	valid_1's auc: 0.908302
# [9000]	training's auc: 0.948469	valid_1's auc: 0.90836
# Early stopping, best iteration is:
# [6920]	training's auc: 0.940187	valid_1's auc: 0.908649
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907535	valid_1's auc: 0.897726
# [2000]	training's auc: 0.915816	valid_1's auc: 0.902966
# [3000]	training's auc: 0.922042	valid_1's auc: 0.905341
# [4000]	training's auc: 0.927353	valid_1's auc: 0.906594
# [5000]	training's auc: 0.932209	valid_1's auc: 0.90727
# [6000]	training's auc: 0.936669	valid_1's auc: 0.907451
# [7000]	training's auc: 0.940876	valid_1's auc: 0.907566
# [8000]	training's auc: 0.944898	valid_1's auc: 0.907604
# [9000]	training's auc: 0.948689	valid_1's auc: 0.907606
# [10000]	training's auc: 0.952397	valid_1's auc: 0.907398
# Early stopping, best iteration is:
# [7696]	training's auc: 0.943677	valid_1's auc: 0.907699
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907006	valid_1's auc: 0.897195
# [2000]	training's auc: 0.915348	valid_1's auc: 0.902562
# [3000]	training's auc: 0.92154	valid_1's auc: 0.905152
# [4000]	training's auc: 0.926853	valid_1's auc: 0.906473
# [5000]	training's auc: 0.931718	valid_1's auc: 0.907157
# [6000]	training's auc: 0.936182	valid_1's auc: 0.90747
# [7000]	training's auc: 0.94045	valid_1's auc: 0.907745
# [8000]	training's auc: 0.94456	valid_1's auc: 0.907801
# [9000]	training's auc: 0.94845	valid_1's auc: 0.90768
# [10000]	training's auc: 0.952182	valid_1's auc: 0.907516
# [11000]	training's auc: 0.955731	valid_1's auc: 0.907467
# Early stopping, best iteration is:
# [8123]	training's auc: 0.945052	valid_1's auc: 0.90785
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907961	valid_1's auc: 0.891273
# [2000]	training's auc: 0.916495	valid_1's auc: 0.896085
# [3000]	training's auc: 0.922659	valid_1's auc: 0.898877
# [4000]	training's auc: 0.927982	valid_1's auc: 0.900381
# [5000]	training's auc: 0.932812	valid_1's auc: 0.901534
# [6000]	training's auc: 0.937265	valid_1's auc: 0.901945
# [7000]	training's auc: 0.941486	valid_1's auc: 0.902123
# [8000]	training's auc: 0.945488	valid_1's auc: 0.902258
# [9000]	training's auc: 0.949326	valid_1's auc: 0.902164
# [10000]	training's auc: 0.953002	valid_1's auc: 0.902134
# [11000]	training's auc: 0.956462	valid_1's auc: 0.901938
# Early stopping, best iteration is:
# [8448]	training's auc: 0.947207	valid_1's auc: 0.902389
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907697	valid_1's auc: 0.891113
# [2000]	training's auc: 0.915915	valid_1's auc: 0.895896
# [3000]	training's auc: 0.922173	valid_1's auc: 0.898794
# [4000]	training's auc: 0.927441	valid_1's auc: 0.900643
# [5000]	training's auc: 0.932233	valid_1's auc: 0.901526
# [6000]	training's auc: 0.936767	valid_1's auc: 0.902114
# [7000]	training's auc: 0.940997	valid_1's auc: 0.902416
# [8000]	training's auc: 0.945026	valid_1's auc: 0.902457
# [9000]	training's auc: 0.94889	valid_1's auc: 0.902251
# [10000]	training's auc: 0.952588	valid_1's auc: 0.902203
# Early stopping, best iteration is:
# [7993]	training's auc: 0.945004	valid_1's auc: 0.902476
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907506	valid_1's auc: 0.890982
# [2000]	training's auc: 0.915978	valid_1's auc: 0.896114
# [3000]	training's auc: 0.922176	valid_1's auc: 0.898982
# [4000]	training's auc: 0.927424	valid_1's auc: 0.900576
# [5000]	training's auc: 0.932248	valid_1's auc: 0.901626
# [6000]	training's auc: 0.936748	valid_1's auc: 0.901956
# [7000]	training's auc: 0.940943	valid_1's auc: 0.902285
# [8000]	training's auc: 0.944993	valid_1's auc: 0.902186
# [9000]	training's auc: 0.948877	valid_1's auc: 0.902246
# [10000]	training's auc: 0.952557	valid_1's auc: 0.902272
# [11000]	training's auc: 0.956044	valid_1's auc: 0.902063
# Early stopping, best iteration is:
# [8601]	training's auc: 0.94736	valid_1's auc: 0.902313
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908278	valid_1's auc: 0.884908
# [2000]	training's auc: 0.916618	valid_1's auc: 0.889476
# [3000]	training's auc: 0.922797	valid_1's auc: 0.892217
# [4000]	training's auc: 0.928061	valid_1's auc: 0.893834
# [5000]	training's auc: 0.93286	valid_1's auc: 0.894655
# [6000]	training's auc: 0.93736	valid_1's auc: 0.895533
# [7000]	training's auc: 0.94158	valid_1's auc: 0.895772
# [8000]	training's auc: 0.945558	valid_1's auc: 0.89596
# [9000]	training's auc: 0.949339	valid_1's auc: 0.896126
# [10000]	training's auc: 0.952973	valid_1's auc: 0.896137
# [11000]	training's auc: 0.956454	valid_1's auc: 0.896143
# [12000]	training's auc: 0.959739	valid_1's auc: 0.895969
# [13000]	training's auc: 0.962887	valid_1's auc: 0.895778
# Early stopping, best iteration is:
# [10173]	training's auc: 0.953583	valid_1's auc: 0.896191
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908436	valid_1's auc: 0.884995
# [2000]	training's auc: 0.91672	valid_1's auc: 0.889536
# [3000]	training's auc: 0.922906	valid_1's auc: 0.891938
# [4000]	training's auc: 0.928193	valid_1's auc: 0.893894
# [5000]	training's auc: 0.933029	valid_1's auc: 0.894934
# [6000]	training's auc: 0.937533	valid_1's auc: 0.895548
# [7000]	training's auc: 0.941775	valid_1's auc: 0.895892
# [8000]	training's auc: 0.945779	valid_1's auc: 0.895966
# [9000]	training's auc: 0.949573	valid_1's auc: 0.896083
# [10000]	training's auc: 0.953192	valid_1's auc: 0.895954
# [11000]	training's auc: 0.956676	valid_1's auc: 0.895947
# [12000]	training's auc: 0.959994	valid_1's auc: 0.895702
# Early stopping, best iteration is:
# [9335]	training's auc: 0.950796	valid_1's auc: 0.896096
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908811	valid_1's auc: 0.884517
# [2000]	training's auc: 0.91709	valid_1's auc: 0.889331
# [3000]	training's auc: 0.923219	valid_1's auc: 0.892042
# [4000]	training's auc: 0.92847	valid_1's auc: 0.893691
# [5000]	training's auc: 0.93325	valid_1's auc: 0.894625
# [6000]	training's auc: 0.937692	valid_1's auc: 0.895253
# [7000]	training's auc: 0.941842	valid_1's auc: 0.895379
# [8000]	training's auc: 0.945779	valid_1's auc: 0.895453
# [9000]	training's auc: 0.949618	valid_1's auc: 0.89544
# [10000]	training's auc: 0.953212	valid_1's auc: 0.895473
# [11000]	training's auc: 0.956692	valid_1's auc: 0.895382
# [12000]	training's auc: 0.959982	valid_1's auc: 0.89516
# [13000]	training's auc: 0.963087	valid_1's auc: 0.895205
# Early stopping, best iteration is:
# [10305]	training's auc: 0.954277	valid_1's auc: 0.895556
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907927	valid_1's auc: 0.887493
# [2000]	training's auc: 0.916381	valid_1's auc: 0.89271
# [3000]	training's auc: 0.922566	valid_1's auc: 0.89502
# [4000]	training's auc: 0.927855	valid_1's auc: 0.89624
# [5000]	training's auc: 0.932722	valid_1's auc: 0.896791
# [6000]	training's auc: 0.937212	valid_1's auc: 0.89701
# [7000]	training's auc: 0.941451	valid_1's auc: 0.896937
# [8000]	training's auc: 0.945525	valid_1's auc: 0.896945
# [9000]	training's auc: 0.949322	valid_1's auc: 0.896832
# Early stopping, best iteration is:
# [6136]	training's auc: 0.937797	valid_1's auc: 0.897108
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.907348	valid_1's auc: 0.887574
# [2000]	training's auc: 0.915746	valid_1's auc: 0.892637
# [3000]	training's auc: 0.922033	valid_1's auc: 0.895373
# [4000]	training's auc: 0.92743	valid_1's auc: 0.896542
# [5000]	training's auc: 0.932288	valid_1's auc: 0.897338
# [6000]	training's auc: 0.936761	valid_1's auc: 0.897546
# [7000]	training's auc: 0.941034	valid_1's auc: 0.897519
# [8000]	training's auc: 0.94508	valid_1's auc: 0.897528
# Early stopping, best iteration is:
# [5694]	training's auc: 0.935423	valid_1's auc: 0.897597
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.908145	valid_1's auc: 0.887227
# [2000]	training's auc: 0.916586	valid_1's auc: 0.892688
# [3000]	training's auc: 0.922847	valid_1's auc: 0.895215
# [4000]	training's auc: 0.928152	valid_1's auc: 0.896311
# [5000]	training's auc: 0.933021	valid_1's auc: 0.896881
# [6000]	training's auc: 0.93745	valid_1's auc: 0.897117
# [7000]	training's auc: 0.941624	valid_1's auc: 0.897128
# [8000]	training's auc: 0.945667	valid_1's auc: 0.897197
# [9000]	training's auc: 0.949496	valid_1's auc: 0.897062
# [10000]	training's auc: 0.95312	valid_1's auc: 0.896958
# [11000]	training's auc: 0.956604	valid_1's auc: 0.896724
# Early stopping, best iteration is:
# [8237]	training's auc: 0.946579	valid_1's auc: 0.897281

# %%
# Submission
predictions['target'] = np.mean(predictions[[col for col in predictions.columns if col not in ['ID_code', 'target']]].values, axis=1)
predictions.to_csv('lgb_all_predictions.csv', index=None)
sub = pd.DataFrame({"ID_code":test["ID_code"].values})
sub["target"] = predictions['target']
sub.to_csv("lgb_submission.csv", index=False)
oof.to_csv('lgb_oof.csv', index=False)

# %%
sub.head()
# Out:
#   ID_code    target
# 0  test_0  0.143490
# 1  test_1  0.284526
# 2  test_2  0.241314
# 3  test_3  0.274705
# 4  test_4  0.061411
